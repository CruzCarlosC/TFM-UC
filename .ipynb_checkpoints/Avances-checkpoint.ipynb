# %% [markdown]
# # <center>Avances TFM</center>

# %% [markdown]
# ### <center>Carlos Andres Cruz Carpio</center>

# %%
from IPython.display import Latex

# %% [markdown]
# El proyecto hasta el momento cuenta con dos scipts
# - tracker.py
# - track.py

# %% [markdown]
# ### Tracker.py

# %% [markdown]
# Contiene descripcion del detector
# - Numero de lados para construir un poligono regular
# - Diferentes "radios", en relacion al circulo circunscrito
# - El poligono es dibujado como una sucesion de rectas que pasan por los puntos del circulo circunscrito
# - La funcion "intersection" evalua si un dado punto(x0,y0) forma parte de alguna de las rectas de los poligonos. Funciona, si existe un solo poligono y redondeando a un decimal. Con mas poligonos, a parte de los puntos de corte aparecen nuevos puntos que no deberian.

# %% [markdown]
# ### Track.py

# %% [markdown]
# Caracteristicas de la trayectoria de la particular
# Toma como base las soluciones de la ecuacion de una particula relativista en un campo uniforme<br>A partir de
# $$\frac{dp^{\alpha}}{d\tau} = q F^{\alpha \beta} u_{\beta}$$ <br>Se llega a
# $$\frac{d\vec{p}}{d\tau} = kq \vec{v} x \vec{B}$$<br>Con $\vec{p} = \gamma m \vec{u}$ y k una constante en funcion de las unidades $k=0.29979 \frac{GeV}{cTm}$ y $w=\frac{qB}{mc\gamma}$<br><br>
# $$x=\frac{p}{w}(cos(wt) - cos(\varphi))$$ <br>
# $$y=\frac{p}{w}(sin(wt) - sin(\varphi))$$ <br>
# Y z puede escribirse en terminos de $\eta$ <br>
# $$z=\frac{p sinh(\eta)}{m \gamma} t$$
# - Usa caracteristicas de un electron en un campo B=4 T

# %% [markdown]
# Probando estas dos clases, con diferentes valores de los parametros se generó los siguientes gifs

# %% [markdown]
# ![scat1.gif](attachment:scat1.gif)

# %% [markdown]
# ![scatter_3.gif](attachment:scatter_3.gif)
